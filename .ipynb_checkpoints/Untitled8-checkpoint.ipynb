# %% [markdown]
# ### 1 -  import the necessary libraries

# %%
import pandas as pd
import random
from textwrap import fill
from openai import OpenAI
client = OpenAI()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2- Project goal
# ### Take complex hematology report text and generate a patient‑friendly explanation using a Generative AI model, starting with a small synthetic dataset.

# %% [markdown]
# ### 3- Let's create a small synthetic hematology dataset

# %%
hematology_reports = [
    {
        "report_id": 1,
        "report_text": (
            "Complete blood count (CBC) shows leukocytosis with neutrophilia. "
            "Hemoglobin is mildly decreased, platelets are within normal limits. "
            "Findings may be consistent with an acute bacterial infection."
        )
    },
    {
        "report_id": 2,
        "report_text": (
            "CBC demonstrates anemia with low hemoglobin and hematocrit. "
            "Mean corpuscular volume (MCV) is decreased, suggesting microcytic anemia, "
            "possibly due to iron deficiency."
        )
    },
    {
        "report_id": 3,
        "report_text": (
            "White blood cell count is decreased (leukopenia), with lymphopenia. "
            "This may be related to recent viral infection or medication effect."
        )
    },
    {
        "report_id": 4,
        "report_text": (
            "Platelet count is significantly reduced (thrombocytopenia). "
            "There is an increased risk of bleeding; clinical correlation is recommended."
        )
    },
    {
        "report_id": 5,
        "report_text": (
            "CBC is within normal limits. No significant abnormalities in white cells, "
            "red cells, or platelets are identified."
        )
    }
]

df = pd.DataFrame(hematology_reports)
df
# Out:
#    report_id                                        report_text
# 0          1  Complete blood count (CBC) shows leukocytosis ...
# 1          2  CBC demonstrates anemia with low hemoglobin an...
# 2          3  White blood cell count is decreased (leukopeni...
# 3          4  Platelet count is significantly reduced (throm...
# 4          5  CBC is within normal limits. No significant ab...

# %% [markdown]
# ### 4 - Inspect the data

# %%
for _, row in df.iterrows():
    print(f"Report ID: {row['report_id']}")
    print(fill(row['report_text'], width=80))
    print("-" * 80)
# Out:
# Report ID: 1
# Complete blood count (CBC) shows leukocytosis with neutrophilia. Hemoglobin is
# mildly decreased, platelets are within normal limits. Findings may be consistent
# with an acute bacterial infection.
# --------------------------------------------------------------------------------
# Report ID: 2
# CBC demonstrates anemia with low hemoglobin and hematocrit. Mean corpuscular
# volume (MCV) is decreased, suggesting microcytic anemia, possibly due to iron
# deficiency.
# --------------------------------------------------------------------------------
# Report ID: 3
# White blood cell count is decreased (leukopenia), with lymphopenia. This may be
# related to recent viral infection or medication effect.
# --------------------------------------------------------------------------------
# Report ID: 4
# Platelet count is significantly reduced (thrombocytopenia). There is an
# increased risk of bleeding; clinical correlation is recommended.
# --------------------------------------------------------------------------------
# Report ID: 5
# CBC is within normal limits. No significant abnormalities in white cells, red
# cells, or platelets are identified.
# --------------------------------------------------------------------------------

# %%
### 5-  Building a simple rule‑based “simplifier”  as a baseline  

### Before using Generative AI, we’ll create a very simple glossary‑based simplifier.
### This gives us a baseline and makes the LLM’s value obvious.

# %%
medical_to_lay = {
    "leukocytosis": "a higher than normal number of white blood cells",
    "neutrophilia": "an increase in a type of white blood cell that fights bacteria",
    "anemia": "a lower than normal number of red blood cells",
    "hemoglobin": "the protein in red blood cells that carries oxygen",
    "hematocrit": "the percentage of blood made up of red blood cells",
    "microcytic": "smaller than normal red blood cells",
    "leukopenia": "a lower than normal number of white blood cells",
    "lymphopenia": "a lower than normal number of lymphocytes, a type of white blood cell",
    "thrombocytopenia": "a lower than normal number of platelets",
    "platelets": "cells that help your blood clot and stop bleeding",
    "CBC": "a complete blood count (CBC), a common blood test",
}

# %%
### Explanation:
### medical_to_lay – maps medical terms to short explanations.
### simple_glossary_simplifier – goes through the text and replaces each term with term (explanation)

# %%
def simple_glossary_simplifier(text, glossary):
    simplified = text
    for term, explanation in glossary.items():
        simplified = simplified.replace(term, f"{term} ({explanation})")
    return simplified

# %% [markdown]
# ### 6 Applying  the baseline simplifier

# %%
df["simplified_baseline"] = df["report_text"].apply(
    lambda t: simple_glossary_simplifier(t, medical_to_lay)
)

for _, row in df.iterrows():
    print(f"Report ID: {row['report_id']}")
    print("Original:")
    print(fill(row['report_text'], width=80))
    print("\nBaseline simplified:")
    print(fill(row['simplified_baseline'], width=80))
    print("=" * 80)
# Out:
# Report ID: 1
# Original:
# Complete blood count (CBC) shows leukocytosis with neutrophilia. Hemoglobin is
# mildly decreased, platelets are within normal limits. Findings may be consistent
# with an acute bacterial infection.
#
# Baseline simplified:
# Complete blood count (CBC (a complete blood count (CBC), a common blood test))
# shows leukocytosis (a higher than normal number of white blood cells) with
# neutrophilia (an increase in a type of white blood cell that fights bacteria).
# Hemoglobin is mildly decreased, platelets (cells that help your blood clot and
# stop bleeding) are within normal limits. Findings may be consistent with an
# acute bacterial infection.
# ================================================================================
# Report ID: 2
# Original:
# CBC demonstrates anemia with low hemoglobin and hematocrit. Mean corpuscular
# volume (MCV) is decreased, suggesting microcytic anemia, possibly due to iron
# deficiency.
#
# Baseline simplified:
# CBC (a complete blood count (CBC), a common blood test) demonstrates anemia (a
# lower than normal number of red blood cells) with low hemoglobin (the protein in
# red blood cells that carries oxygen) and hematocrit (the percentage of blood
# made up of red blood cells). Mean corpuscular volume (MCV) is decreased,
# suggesting microcytic (smaller than normal red blood cells) anemia (a lower than
# normal number of red blood cells), possibly due to iron deficiency.
# ================================================================================
# Report ID: 3
# Original:
# White blood cell count is decreased (leukopenia), with lymphopenia. This may be
# related to recent viral infection or medication effect.
#
# Baseline simplified:
# White blood cell count is decreased (leukopenia (a lower than normal number of
# white blood cells)), with lymphopenia (a lower than normal number of
# lymphocytes, a type of white blood cell). This may be related to recent viral
# infection or medication effect.
# ================================================================================
# Report ID: 4
# Original:
# Platelet count is significantly reduced (thrombocytopenia). There is an
# increased risk of bleeding; clinical correlation is recommended.
#
# Baseline simplified:
# Platelet count is significantly reduced (thrombocytopenia (a lower than normal
# number of platelets (cells that help your blood clot and stop bleeding))). There
# is an increased risk of bleeding; clinical correlation is recommended.
# ================================================================================
# Report ID: 5
# Original:
# CBC is within normal limits. No significant abnormalities in white cells, red
# cells, or platelets are identified.
#
# Baseline simplified:
# CBC (a complete blood count (CBC), a common blood test) is within normal limits.
# No significant abnormalities in white cells, red cells, or platelets (cells that
# help your blood clot and stop bleeding) are identified.
# ================================================================================

# %%
### In the above, we created a new column, simplified_baseline. For each report, we show: 
### Original text 
### Baseline simplified version with inline explanations.
### This is still not truly patient‑friendly, but it’s a good starting point.

# %% [markdown]
# ### 7 - Add a Generative AI layer (LLM) – structure

# %%
### Now we design how we’d call a Generative AI model. 
### I’ll show the structure using a generic call_llm() function—you can plug in your provider (OpenAI, Azure, etc.).

### Explanation:
### system_instructions – sets the role and constraints for the model.
### user_prompt – gives the actual report and asks for a simplified explanation.
### We return both so they can be passed to an LLM API.

# %%
def build_prompt(report_text):
    system_instructions = (
        "You are a clinical educator. Your job is to rewrite hematology lab reports "
        "so that a non-medical patient can understand them. Preserve the medical "
        "meaning, do not add new diagnoses, and avoid giving medical advice. "
        "Use short sentences and simple language at about an 8th grade reading level."
    )

    user_prompt = (
        "Rewrite the following hematology report in patient-friendly language. "
        "You may explain medical terms, but do not change the meaning.\n\n"
        f"Report:\n{report_text}\n\n"
        "Patient-friendly explanation:"
    )

    return system_instructions, user_prompt

# %% [markdown]
# ### 8 -  Pseudo‑code for calling an LLM

# %% [markdown]
# ### You’d replace call_llm with your actual API call. Here’s the structure:

# %%
def call_llm(system_message, user_message):
    """
    Pseudo-code placeholder.
    Replace this with your actual LLM API call.
    """
    # Example structure (OpenAI-style, but commented out):
    #
    # from openai import OpenAI
    # client = OpenAI()
    # response = client.chat.completions.create(
    #     model="gpt-4o-mini",
    #     messages=[
    #         {"role": "system", "content": system_message},
    #         {"role": "user", "content": user_message},
    #     ],
    #     temperature=0.3,
    # )
    # return response.choices[0].message.content.strip()
    #
    # For now, we just return a placeholder:
    return "PLACEHOLDER: This is where the LLM's simplified explanation would appear."

# %%
###  Explanation:
### The above function shows how you’d integrate a real LLM.
### In your environment, you’d:
### Import the client
### Pass system_message and user_message
### Return the model’s text.

# %% [markdown]
# ### 9 -  Generate LLM‑based simplifications for each report

# %%
simplified_llm_outputs = []

for _, row in df.iterrows():
    system_msg, user_msg = build_prompt(row["report_text"])
    simplified_text = call_llm(system_msg, user_msg)
    simplified_llm_outputs.append(simplified_text)

df["simplified_llm"] = simplified_llm_outputs
df[["report_id", "report_text", "simplified_baseline", "simplified_llm"]]


### Explanation:
### For each report:
### Build a prompt
### Call the LLM
### Store the result in simplified_llm_outputs
### Then we add a new column simplified_llm to the DataFrame.
### Once you plug in a real model, this column will contain true generative simplifications.
# Out:
#    report_id                                        report_text  \
# 0          1  Complete blood count (CBC) shows leukocytosis ...
# 1          2  CBC demonstrates anemia with low hemoglobin an...
# 2          3  White blood cell count is decreased (leukopeni...
# 3          4  Platelet count is significantly reduced (throm...
# 4          5  CBC is within normal limits. No significant ab...
#
#                                  simplified_baseline  \
# 0  Complete blood count (CBC (a complete blood co...
# 1  CBC (a complete blood count (CBC), a common bl...
# 2  White blood cell count is decreased (leukopeni...
# 3  Platelet count is significantly reduced (throm...
# 4  CBC (a complete blood count (CBC), a common bl...
#
#                                       simplified_llm
# 0  PLACEHOLDER: This is where the LLM's simplifie...
# 1  PLACEHOLDER: This is where the LLM's simplifie...
# 2  PLACEHOLDER: This is where the LLM's simplifie...
# 3  PLACEHOLDER: This is where the LLM's simplifie...
# 4  PLACEHOLDER: This is where the LLM's simplifie...

# %% [markdown]
# ###  10 - Compare outputs side by side

# %%
for _, row in df.iterrows():
    print(f"Report ID: {row['report_id']}")
    print("\nOriginal report:")
    print(fill(row["report_text"], width=80))

    print("\nBaseline (glossary) simplification:")
    print(fill(row["simplified_baseline"], width=80))

    print("\nLLM-based simplification:")
    print(fill(row["simplified_llm"], width=80))

    print("=" * 100)
# Out:
# Report ID: 1
#
# Original report:
# Complete blood count (CBC) shows leukocytosis with neutrophilia. Hemoglobin is
# mildly decreased, platelets are within normal limits. Findings may be consistent
# with an acute bacterial infection.
#
# Baseline (glossary) simplification:
# Complete blood count (CBC (a complete blood count (CBC), a common blood test))
# shows leukocytosis (a higher than normal number of white blood cells) with
# neutrophilia (an increase in a type of white blood cell that fights bacteria).
# Hemoglobin is mildly decreased, platelets (cells that help your blood clot and
# stop bleeding) are within normal limits. Findings may be consistent with an
# acute bacterial infection.
#
# LLM-based simplification:
# PLACEHOLDER: This is where the LLM's simplified explanation would appear.
# ====================================================================================================
# Report ID: 2
#
# Original report:
# CBC demonstrates anemia with low hemoglobin and hematocrit. Mean corpuscular
# volume (MCV) is decreased, suggesting microcytic anemia, possibly due to iron
# deficiency.
#
# Baseline (glossary) simplification:
# CBC (a complete blood count (CBC), a common blood test) demonstrates anemia (a
# lower than normal number of red blood cells) with low hemoglobin (the protein in
# red blood cells that carries oxygen) and hematocrit (the percentage of blood
# made up of red blood cells). Mean corpuscular volume (MCV) is decreased,
# suggesting microcytic (smaller than normal red blood cells) anemia (a lower than
# normal number of red blood cells), possibly due to iron deficiency.
#
# LLM-based simplification:
# PLACEHOLDER: This is where the LLM's simplified explanation would appear.
# ====================================================================================================
# Report ID: 3
#
# Original report:
# White blood cell count is decreased (leukopenia), with lymphopenia. This may be
# related to recent viral infection or medication effect.
#
# Baseline (glossary) simplification:
# White blood cell count is decreased (leukopenia (a lower than normal number of
# white blood cells)), with lymphopenia (a lower than normal number of
# lymphocytes, a type of white blood cell). This may be related to recent viral
# infection or medication effect.
#
# LLM-based simplification:
# PLACEHOLDER: This is where the LLM's simplified explanation would appear.
# ====================================================================================================
# Report ID: 4
#
# Original report:
# Platelet count is significantly reduced (thrombocytopenia). There is an
# increased risk of bleeding; clinical correlation is recommended.
#
# Baseline (glossary) simplification:
# Platelet count is significantly reduced (thrombocytopenia (a lower than normal
# number of platelets (cells that help your blood clot and stop bleeding))). There
# is an increased risk of bleeding; clinical correlation is recommended.
#
# LLM-based simplification:
# PLACEHOLDER: This is where the LLM's simplified explanation would appear.
# ====================================================================================================
# Report ID: 5
#
# Original report:
# CBC is within normal limits. No significant abnormalities in white cells, red
# cells, or platelets are identified.
#
# Baseline (glossary) simplification:
# CBC (a complete blood count (CBC), a common blood test) is within normal limits.
# No significant abnormalities in white cells, red cells, or platelets (cells that
# help your blood clot and stop bleeding) are identified.
#
# LLM-based simplification:
# PLACEHOLDER: This is where the LLM's simplified explanation would appear.
# ====================================================================================================

# %%
### Explanation:
### This gives you a human‑readable comparison:
### Original
### Rule‑based baseline
### Generative AI version

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
def call_llm(text):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You simplify hematology lab reports into plain English."},
            {"role": "user", "content": text}
        ]
    )
    return response.choices[0].message["content"]

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_name = "microsoft/Phi-3-mini-4k-instruct"

pipe = pipeline(
    "text-generation",
    model=model_name,
    tokenizer=model_name,
    dtype="auto",        # updated parameter name
    device_map="auto",   # uses GPU if available
    max_new_tokens=120   # faster generation
)
# Out:
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %%
def simplify_hematology(text):
    prompt = f"Simplify this hematology lab report into plain English:\n\n{text}\n\nExplanation:"
    result = pipe(prompt)[0]["generated_text"]
    return result

# %%
sample = """
WBC: 14.2 (High)
Hemoglobin: 9.8 (Low)
Platelets: 420 (High)
"""

print(simplify_hematology(sample))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 sample = """
#       2 WBC: 14.2 (High)
#       3 Hemoglobin: 9.8 (Low)
#       4 Platelets: 420 (High)
#       5 """
# ----> 7 print(simplify_hematology(sample))
#
# Cell In[3], line 3, in simplify_hematology(text)
#       1 def simplify_hematology(text):
#       2     prompt = f"Simplify this hematology lab report into plain English:\n\n{text}\n\nExplanation:"
# ----> 3     result = pipe(prompt)[0]["generated_text"]
#       4     return result
#
# NameError: name 'pipe' is not defined

# %%
import pandas as pd
import random

def generate_random_lab_report():
    # Random but clinically plausible ranges
    wbc = round(random.uniform(3.0, 20.0), 1)          # x10^9/L
    hgb = round(random.uniform(6.0, 18.0), 1)          # g/dL
    plt = random.randint(50, 600)                      # x10^9/L

    # Flags
    if wbc < 4.0:
        wbc_flag = "Low"
    elif wbc > 11.0:
        wbc_flag = "High"
    else:
        wbc_flag = "Normal"

    if hgb < 12.0:
        hgb_flag = "Low"
    elif hgb > 17.0:
        hgb_flag = "High"
    else:
        hgb_flag = "Normal"

    if plt < 150:
        plt_flag = "Low"
    elif plt > 450:
        plt_flag = "High"
    else:
        plt_flag = "Normal"

    report = f"""
WBC: {wbc} ({wbc_flag})
Hemoglobin: {hgb} ({hgb_flag})
Platelets: {plt} ({plt_flag})
"""
    return report.strip()

# Generate 1000 synthetic reports
records = []
for i in range(1, 1001):
    records.append({
        "id": i,
        "report": generate_random_lab_report()
    })

df = pd.DataFrame(records)
df.head()

# %%
import pandas as pd

df_check = pd.read_csv("hematology_reports_1000.csv")

# %%
df_check.head()
df_check.tail()

# %%
df.to_csv("hematology_reports_1000.csv", index=False)

# %%
df_check["id"].nunique()
# Out:
# 1000

# %%
df_check["report"].isna().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

df = pd.read_csv("hematology_reports_1000.csv")
df.head()
# Out:
#    id                                             report
# 0   1  WBC: 16.7 (High)\nHemoglobin: 14.5 (Normal)\nP...
# 1   2  WBC: 15.5 (High)\nHemoglobin: 16.6 (Normal)\nP...
# 2   3  WBC: 19.9 (High)\nHemoglobin: 13.6 (Normal)\nP...
# 3   4  WBC: 15.2 (High)\nHemoglobin: 7.5 (Low)\nPlate...
# 4   5  WBC: 8.2 (Normal)\nHemoglobin: 6.6 (Low)\nPlat...

# %%
def batch_simplify(df, text_column="report"):
    simplified = []
    
    for text in df[text_column]:
        explanation = simplify_hematology(text)
        simplified.append(explanation)
    
    df["simplified"] = simplified
    return df

# %%
df_processed = batch_simplify(df)
df_processed.head()
# Out:
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_processed = batch_simplify(df)
#       2 df_processed.head()
#
# Cell In[15], line 5, in batch_simplify(df, text_column)
#       2 simplified = []
#       4 for text in df[text_column]:
# ----> 5     explanation = simplify_hematology(text)
#       6     simplified.append(explanation)
#       8 df["simplified"] = simplified
#
# Cell In[1], line 3, in simplify_hematology(text)
#       1 def simplify_hematology(text):
#       2     prompt = f"Simplify this hematology lab report into plain English:\n\n{text}\n\nExplanation:"
# ----> 3     result = pipe(prompt)[0]["generated_text"]
#       4     return result
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\pipelines\text_generation.py:299, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     249 def __call__(self, text_inputs, **kwargs):
#     250     """
#     251     Complete the prompt(s) given as inputs.
#     252
#    (...)
#     297           ids of the generated text.
#     298     """
# --> 299     return super().__call__(text_inputs, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\pipelines\base.py:1267, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1259     return next(
#    1260         iter(
#    1261             self.get_iterator(
#    (...)
#    1264         )
#    1265     )
#    1266 else:
# -> 1267     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\pipelines\base.py:1274, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1272 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1273     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1274     model_outputs = self.forward(model_inputs, **forward_params)
#    1275     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1276     return outputs
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\pipelines\base.py:1166, in Pipeline.forward(self, model_inputs, **forward_params)
#    1164     with inference_context():
#    1165         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1166         model_outputs = self._forward(model_inputs, **forward_params)
#    1167         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1168 return model_outputs
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\pipelines\text_generation.py:403, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     400 if "generation_config" not in generate_kwargs:
#     401     generate_kwargs["generation_config"] = self.generation_config
# --> 403 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     405 if isinstance(output, ModelOutput):
#     406     generated_sequence = output.sequences
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\generation\utils.py:2535, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2532 model_kwargs["use_cache"] = generation_config.use_cache
#    2534 # 9. Call generation mode
# -> 2535 result = decoding_method(
#    2536     self,
#    2537     input_ids,
#    2538     logits_processor=prepared_logits_processor,
#    2539     stopping_criteria=prepared_stopping_criteria,
#    2540     generation_config=generation_config,
#    2541     **generation_mode_kwargs,
#    2542     **model_kwargs,
#    2543 )
#    2545 return result
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\generation\utils.py:2742, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2738     model_inputs = self.prepare_inputs_for_generation(
#    2739         input_ids, next_sequence_length=next_sequence_length, **model_kwargs
#    2740     )
#    2741     with self._optimize_model_for_decode():
# -> 2742         outputs = model_forward(**model_inputs, return_dict=True)
#    2743 prefill_consumed = True
#    2744 model_kwargs = self._update_model_kwargs_for_generation(
#    2745     outputs,
#    2746     model_kwargs,
#    2747     is_encoder_decoder=self.config.is_encoder_decoder,
#    2748 )
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\utils\generic.py:843, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     841 if return_dict_passed is not None:
#     842     return_dict = return_dict_passed
# --> 843 output = func(self, *args, **kwargs)
#     844 if not return_dict and not isinstance(output, tuple):
#     845     output = output.to_tuple()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\models\phi3\modeling_phi3.py:491, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     459 @can_return_tuple
#     460 @auto_docstring
#     461 def forward(
#    (...)
#     472     **kwargs: Unpack[TransformersKwargs],
#     473 ) -> CausalLMOutputWithPast:
#     474     r"""
#     475     Example:
#     476
#    (...)
#     489     "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     490     ```"""
# --> 491     outputs: BaseModelOutputWithPast = self.model(
#     492         input_ids=input_ids,
#     493         attention_mask=attention_mask,
#     494         position_ids=position_ids,
#     495         past_key_values=past_key_values,
#     496         inputs_embeds=inputs_embeds,
#     497         use_cache=use_cache,
#     498         cache_position=cache_position,
#     499         **kwargs,
#     500     )
#     502     hidden_states = outputs.last_hidden_state
#     503     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\utils\generic.py:917, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     915             output = func(self, *args, **kwargs)
#     916     else:
# --> 917         output = func(self, *args, **kwargs)
#     918 # Restore original config value
#     919 finally:
#     920     if is_causal is not None:
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\utils\output_capturing.py:253, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     251 # Run the forward
#     252 try:
# --> 253     outputs = func(self, *args, **kwargs)
#     254 # Reset the states
#     255 finally:
#     256     _active_collector.reset(output_token)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\models\phi3\modeling_phi3.py:427, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     424 position_embeddings = self.rotary_emb(hidden_states, position_ids=position_ids)
#     426 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 427     hidden_states = decoder_layer(
#     428         hidden_states,
#     429         attention_mask=causal_mask,
#     430         position_ids=position_ids,
#     431         past_key_values=past_key_values,
#     432         use_cache=use_cache,
#     433         cache_position=cache_position,
#     434         position_embeddings=position_embeddings,
#     435         **kwargs,
#     436     )
#     437 hidden_states = self.norm(hidden_states)
#     438 return BaseModelOutputWithPast(
#     439     last_hidden_state=hidden_states,
#     440     past_key_values=past_key_values if use_cache else None,
#     441 )
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\models\phi3\modeling_phi3.py:338, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     336 residual = hidden_states
#     337 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 338 hidden_states = self.mlp(hidden_states)
#     339 hidden_states = residual + self.resid_mlp_dropout(hidden_states)  # main diff with Llama
#     340 return hidden_states
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\transformers\models\phi3\modeling_phi3.py:59, in Phi3MLP.forward(self, hidden_states)
#      58 def forward(self, hidden_states: torch.FloatTensor) -> torch.FloatTensor:
# ---> 59     up_states = self.gate_up_proj(hidden_states)
#      61     gate, up_states = up_states.chunk(2, dim=-1)
#      62     up_states = up_states * self.activation_fn(gate)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\AppData\Local\r-miniconda\lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm

def batch_simplify_with_progress(df, text_column="report"):
    simplified = []
    
    for text in tqdm(df[text_column], desc="Simplifying reports"):
        explanation = simplify_hematology(text)
        simplified.append(explanation)
    
    df["simplified"] = simplified
    return df
