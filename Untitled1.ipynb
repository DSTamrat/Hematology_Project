# %%
import pandas as pd

full_path = r"C:\Users\Tamrat\Desktop\Hematology_Project\datasets\hematology_datasets.csv"
df = pd.read_csv(full_path)
df.shape
# Out:
# (1000, 2)

# %%
df_sample = df.sample(n=10, random_state=42)
df_sample.shape
# Out:
# (10, 2)

# %%
sample_path = r"C:\Users\Tamrat\Desktop\Hematology_Project\hematology-nlp-simplifier\sample_data\sample_hematology_reports.csv"
df_sample.to_csv(sample_path, index=False)

# %%
test_sample = pd.read_csv(sample_path)
test_sample.head()
# Out:
#     id                                             report
# 0  522  WBC: 7.5 (Normal)\nHemoglobin: 16.5 (Normal)\n...
# 1  738  WBC: 14.0 (High)\nHemoglobin: 7.7 (Low)\nPlate...
# 2  741  WBC: 5.5 (Normal)\nHemoglobin: 11.7 (Low)\nPla...
# 3  661  WBC: 14.2 (High)\nHemoglobin: 8.0 (Low)\nPlate...
# 4  412  WBC: 5.0 (Normal)\nHemoglobin: 9.9 (Low)\nPlat...
